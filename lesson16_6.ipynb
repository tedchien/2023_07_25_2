# %%
import random
def get_score() -> list:
    score = []
    for i in range(5):
        score.append(random.randint(50, 100))
    return score

def get_names(nums:int) -> list:
    with open('names.txt',encoding='utf-8',newline='') as file:
        names_str = file.read()
        all_names_list = names_str.split(sep="\n")
        names_list = random.choices(all_names_list,k=nums) #取出一定數量的姓名
    return names_list

nums_int = int(input("請輸入學生數:"))
#取得nums_int個姓名
names_list = get_names(nums_int)
students = []
for i in range(nums_int):
    scores = get_score()
    new_list = [names_list[i]] + scores
    students.append(new_list)
students
# Out:
# [['李淑芳', 73, 99, 59, 76, 53],
#  ['郭淑枝', 91, 97, 95, 74, 76],
#  ['張嘉韋', 90, 62, 85, 63, 60],
#  ['高士凱', 73, 88, 96, 96, 94],
#  ['林義皓', 76, 50, 82, 71, 67],
#  ['李政白', 84, 81, 87, 64, 92],
#  ['陳美惠', 54, 65, 65, 64, 87],
#  ['吳晴洋', 58, 50, 55, 50, 93],
#  ['林志成', 88, 97, 80, 81, 81],
#  ['陳怡伶', 100, 93, 78, 99, 77],
#  ['劉萬季', 53, 80, 80, 60, 84],
#  ['林麗萍', 52, 57, 54, 77, 93],
#  ['潘俊賢', 54, 100, 50, 86, 77],
#  ['余宗儒', 54, 53, 69, 89, 61],
#  ['龐皓芳', 64, 87, 84, 63, 97],
#  ['吳晴洋', 66, 54, 89, 56, 84],
#  ['陳得映', 68, 50, 100, 63, 82],
#  ['楊建安', 86, 94, 64, 55, 100],
#  ['藍哲嘉', 51, 72, 60, 86, 60],
#  ['羅佩樺', 76, 59, 68, 80, 72],
#  ['馮芳如', 59, 66, 60, 92, 71],
#  ['陳怡珊', 63, 66, 60, 62, 76],
#  ['黃靜怡', 98, 64, 53, 90, 98],
#  ['潘英迪', 74, 99, 84, 80, 88],
#  ['盧冠發', 96, 90, 84, 100, 99],
#  ['張牧聿', 87, 98, 54, 65, 74],
#  ['陳建豪', 78, 59, 71, 69, 53],
#  ['羅佩樺', 75, 68, 54, 53, 99],
#  ['陳信宏', 53, 59, 94, 72, 78],
#  ['詹忠光', 73, 83, 50, 85, 82],
#  ['黃佩芬', 98, 86, 84, 78, 62],
#  ['戴萱能', 50, 94, 90, 78, 99],
#  ['王士銘', 91, 63, 55, 100, 92],
#  ['簡佳樺', 75, 54, 83, 95, 77],
#  ['李慶亮', 63, 92, 60, 73, 57],
#  ['蕭淑華', 86, 93, 76, 68, 67],
#  ['王士銘', 88, 50, 87, 52, 60],
#  ['金宜芳', 61, 99, 77, 55, 74],
#  ['楊建安', 98, 86, 63, 63, 87],
#  ['林俊翔', 76, 88, 74, 67, 61],
#  ['梁柏宇', 98, 93, 60, 76, 100],
#  ['蕭怡伶', 69, 61, 58, 88, 60],
#  ['陳嘉淑', 65, 73, 59, 62, 90],
#  ['陳淑娟', 65, 56, 84, 61, 52],
#  ['賴又琦', 65, 100, 75, 67, 92],
#  ['王梅劭', 72, 90, 68, 64, 54],
#  ['郎慧萍', 62, 53, 56, 52, 80],
#  ['黃旻林', 80, 58, 57, 61, 78],
#  ['姜琬婷', 81, 68, 63, 88, 75],
#  ['高信宏', 70, 90, 60, 89, 54]]

# %%
import pandas as pd

#students_df = pd.DataFrame(students)
#students_df = pd.DataFrame(students,columns=['姓名','國文','英文','數學','地理','歷史'])
students_df = pd.DataFrame(students,columns=['姓名','國文','英文','數學','地理','歷史'],index=range(1,nums_int+1))
students_df
# Out:
#      姓名   國文   英文   數學   地理   歷史
# 1   李淑芳   73   99   59   76   53
# 2   郭淑枝   91   97   95   74   76
# 3   張嘉韋   90   62   85   63   60
# 4   高士凱   73   88   96   96   94
# 5   林義皓   76   50   82   71   67
# 6   李政白   84   81   87   64   92
# 7   陳美惠   54   65   65   64   87
# 8   吳晴洋   58   50   55   50   93
# 9   林志成   88   97   80   81   81
# 10  陳怡伶  100   93   78   99   77
# 11  劉萬季   53   80   80   60   84
# 12  林麗萍   52   57   54   77   93
# 13  潘俊賢   54  100   50   86   77
# 14  余宗儒   54   53   69   89   61
# 15  龐皓芳   64   87   84   63   97
# 16  吳晴洋   66   54   89   56   84
# 17  陳得映   68   50  100   63   82
# 18  楊建安   86   94   64   55  100
# 19  藍哲嘉   51   72   60   86   60
# 20  羅佩樺   76   59   68   80   72
# 21  馮芳如   59   66   60   92   71
# 22  陳怡珊   63   66   60   62   76
# 23  黃靜怡   98   64   53   90   98
# 24  潘英迪   74   99   84   80   88
# 25  盧冠發   96   90   84  100   99
# 26  張牧聿   87   98   54   65   74
# 27  陳建豪   78   59   71   69   53
# 28  羅佩樺   75   68   54   53   99
# 29  陳信宏   53   59   94   72   78
# 30  詹忠光   73   83   50   85   82
# 31  黃佩芬   98   86   84   78   62
# 32  戴萱能   50   94   90   78   99
# 33  王士銘   91   63   55  100   92
# 34  簡佳樺   75   54   83   95   77
# 35  李慶亮   63   92   60   73   57
# 36  蕭淑華   86   93   76   68   67
# 37  王士銘   88   50   87   52   60
# 38  金宜芳   61   99   77   55   74
# 39  楊建安   98   86   63   63   87
# 40  林俊翔   76   88   74   67   61
# 41  梁柏宇   98   93   60   76  100
# 42  蕭怡伶   69   61   58   88   60
# 43  陳嘉淑   65   73   59   62   90
# 44  陳淑娟   65   56   84   61   52
# 45  賴又琦   65  100   75   67   92
# 46  王梅劭   72   90   68   64   54
# 47  郎慧萍   62   53   56   52   80
# 48  黃旻林   80   58   57   61   78
# 49  姜琬婷   81   68   63   88   75
# 50  高信宏   70   90   60   89   54
