# %%
import pandas as pd
data = {"字串":["台北", "台中"],
        "整數":[1000, 3000],
        "浮點數":[3.258, 7.396]}

df = pd.DataFrame(data)
display(df)
# Out:
#    字串    整數    浮點數
# 0  台北  1000  3.258
# 1  台中  3000  7.396

# %%
#視覺美化資料表
#pip install jinja2
df.style\
.format(precision=2,thousands=",",decimal=".")\
.relabel_index(["列1","列2"])
# Out:
# <style type="text/css">
# </style>
# <table id="T_77311">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_77311_level0_col0" class="col_heading level0 col0" >字串</th>
#       <th id="T_77311_level0_col1" class="col_heading level0 col1" >整數</th>
#       <th id="T_77311_level0_col2" class="col_heading level0 col2" >浮點數</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_77311_level0_row0" class="row_heading level0 row0" >列1</th>
#       <td id="T_77311_row0_col0" class="data row0 col0" >台北</td>
#       <td id="T_77311_row0_col1" class="data row0 col1" >1,000</td>
#       <td id="T_77311_row0_col2" class="data row0 col2" >3.26</td>
#     </tr>
#     <tr>
#       <th id="T_77311_level0_row1" class="row_heading level0 row1" >列2</th>
#       <td id="T_77311_row1_col0" class="data row1 col0" >台中</td>
#       <td id="T_77311_row1_col1" class="data row1 col1" >3,000</td>
#       <td id="T_77311_row1_col2" class="data row1 col2" >7.40</td>
#     </tr>
#   </tbody>
# </table>

# %%
import numpy as np
data = np.random.rand(10,2) * 5
df = pd.DataFrame(data,
                  index = pd.date_range(start="2023-09-01",periods=10),
                  columns=["台北","台中"]
                  )
df
# Out:
#                   台北        台中
# 2023-09-01  0.112301  3.771873
# 2023-09-02  1.319694  4.679133
# 2023-09-03  1.124464  1.409098
# 2023-09-04  1.565393  2.725687
# 2023-09-05  4.626591  1.525138
# 2023-09-06  2.926016  4.876927
# 2023-09-07  0.239630  3.640679
# 2023-09-08  2.016265  3.158368
# 2023-09-09  2.201014  0.126030
# 2023-09-10  2.162558  4.812659

# %%
#視覺美化資料表
def feel_condition(v):
    if v < 1.75:
        return "溫暖"
    elif v < 2.75:
        return "潮溼"
    else:
        return "日照"
    
df.style\
.format(feel_condition)\
.set_caption("體感溫度")\
.background_gradient(cmap="PuBuGn",vmin=1,vmax=5,axis=None)
# Out:
# <style type="text/css">
# #T_ec202_row0_col0, #T_ec202_row6_col0, #T_ec202_row8_col1 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_ec202_row0_col1 {
#   background-color: #1988a2;
#   color: #f1f1f1;
# }
# #T_ec202_row1_col0 {
#   background-color: #f3eaf4;
#   color: #000000;
# }
# #T_ec202_row1_col1 {
#   background-color: #015e4c;
#   color: #f1f1f1;
# }
# #T_ec202_row2_col0 {
#   background-color: #fbf2f9;
#   color: #000000;
# }
# #T_ec202_row2_col1 {
#   background-color: #f0e6f2;
#   color: #000000;
# }
# #T_ec202_row3_col0 {
#   background-color: #e8e0ef;
#   color: #000000;
# }
# #T_ec202_row3_col1 {
#   background-color: #8ab4d6;
#   color: #000000;
# }
# #T_ec202_row4_col0 {
#   background-color: #01614f;
#   color: #f1f1f1;
# }
# #T_ec202_row4_col1 {
#   background-color: #ebe1f0;
#   color: #000000;
# }
# #T_ec202_row5_col0 {
#   background-color: #70acd1;
#   color: #f1f1f1;
# }
# #T_ec202_row5_col1 {
#   background-color: #014e3e;
#   color: #f1f1f1;
# }
# #T_ec202_row6_col1 {
#   background-color: #268bb0;
#   color: #f1f1f1;
# }
# #T_ec202_row7_col0 {
#   background-color: #ced0e6;
#   color: #000000;
# }
# #T_ec202_row7_col1 {
#   background-color: #57a1ca;
#   color: #f1f1f1;
# }
# #T_ec202_row8_col0 {
#   background-color: #c0c9e2;
#   color: #000000;
# }
# #T_ec202_row9_col0 {
#   background-color: #c2cbe2;
#   color: #000000;
# }
# #T_ec202_row9_col1 {
#   background-color: #015342;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_ec202">
#   <caption>體感溫度</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ec202_level0_col0" class="col_heading level0 col0" >台北</th>
#       <th id="T_ec202_level0_col1" class="col_heading level0 col1" >台中</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ec202_level0_row0" class="row_heading level0 row0" >2023-09-01 00:00:00</th>
#       <td id="T_ec202_row0_col0" class="data row0 col0" >溫暖</td>
#       <td id="T_ec202_row0_col1" class="data row0 col1" >日照</td>
#     </tr>
#     <tr>
#       <th id="T_ec202_level0_row1" class="row_heading level0 row1" >2023-09-02 00:00:00</th>
#       <td id="T_ec202_row1_col0" class="data row1 col0" >溫暖</td>
#       <td id="T_ec202_row1_col1" class="data row1 col1" >日照</td>
#     </tr>
#     <tr>
#       <th id="T_ec202_level0_row2" class="row_heading level0 row2" >2023-09-03 00:00:00</th>
#       <td id="T_ec202_row2_col0" class="data row2 col0" >溫暖</td>
#       <td id="T_ec202_row2_col1" class="data row2 col1" >溫暖</td>
#     </tr>
#     <tr>
#       <th id="T_ec202_level0_row3" class="row_heading level0 row3" >2023-09-04 00:00:00</th>
#       <td id="T_ec202_row3_col0" class="data row3 col0" >溫暖</td>
#       <td id="T_ec202_row3_col1" class="data row3 col1" >潮溼</td>
#     </tr>
#     <tr>
#       <th id="T_ec202_level0_row4" class="row_heading level0 row4" >2023-09-05 00:00:00</th>
#       <td id="T_ec202_row4_col0" class="data row4 col0" >日照</td>
#       <td id="T_ec202_row4_col1" class="data row4 col1" >溫暖</td>
#     </tr>
#     <tr>
#       <th id="T_ec202_level0_row5" class="row_heading level0 row5" >2023-09-06 00:00:00</th>
#       <td id="T_ec202_row5_col0" class="data row5 col0" >日照</td>
#       <td id="T_ec202_row5_col1" class="data row5 col1" >日照</td>
#     </tr>
#     <tr>
#       <th id="T_ec202_level0_row6" class="row_heading level0 row6" >2023-09-07 00:00:00</th>
#       <td id="T_ec202_row6_col0" class="data row6 col0" >溫暖</td>
#       <td id="T_ec202_row6_col1" class="data row6 col1" >日照</td>
#     </tr>
#     <tr>
#       <th id="T_ec202_level0_row7" class="row_heading level0 row7" >2023-09-08 00:00:00</th>
#       <td id="T_ec202_row7_col0" class="data row7 col0" >潮溼</td>
#       <td id="T_ec202_row7_col1" class="data row7 col1" >日照</td>
#     </tr>
#     <tr>
#       <th id="T_ec202_level0_row8" class="row_heading level0 row8" >2023-09-09 00:00:00</th>
#       <td id="T_ec202_row8_col0" class="data row8 col0" >潮溼</td>
#       <td id="T_ec202_row8_col1" class="data row8 col1" >溫暖</td>
#     </tr>
#     <tr>
#       <th id="T_ec202_level0_row9" class="row_heading level0 row9" >2023-09-10 00:00:00</th>
#       <td id="T_ec202_row9_col0" class="data row9 col0" >潮溼</td>
#       <td id="T_ec202_row9_col1" class="data row9 col1" >日照</td>
#     </tr>
#   </tbody>
# </table>

# %%
#隱藏資料
df = pd.DataFrame(np.random.randn(5,5))
df.style\
.hide(subset=[0, 2, 4],axis=0)\
.hide(subset=[1,3],axis=1)
# Out:
# <style type="text/css">
# </style>
# <table id="T_84f07">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_84f07_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_84f07_level0_col2" class="col_heading level0 col2" >2</th>
#       <th id="T_84f07_level0_col4" class="col_heading level0 col4" >4</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_84f07_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_84f07_row1_col0" class="data row1 col0" >0.156844</td>
#       <td id="T_84f07_row1_col2" class="data row1 col2" >1.197632</td>
#       <td id="T_84f07_row1_col4" class="data row1 col4" >-0.892098</td>
#     </tr>
#     <tr>
#       <th id="T_84f07_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_84f07_row3_col0" class="data row3 col0" >0.788295</td>
#       <td id="T_84f07_row3_col2" class="data row3 col2" >-0.392145</td>
#       <td id="T_84f07_row3_col4" class="data row3 col4" >-0.857266</td>
#     </tr>
#   </tbody>
# </table>

# %%
df = pd.DataFrame(np.random.randn(10,4),
             columns=["A", "B", "C", "D"])
display(df)

def style_negative(v, props=''):
    return props if v < 0 else None

df.style\
.map(style_negative,props='color:red;')
# Out:
#           A         B         C         D
# 0 -0.141269 -1.913170 -0.118287  0.129955
# 1  0.553204  1.609483 -0.615517 -0.041524
# 2  0.011620  2.429812 -0.508310  0.714850
# 3 -0.270485  1.616712  0.469772 -0.991215
# 4  1.558983  1.644725  1.566035  1.347889
# 5 -0.756450 -0.417384 -0.296340 -0.257459
# 6  0.154251  0.862215 -1.660832 -0.040017
# 7  0.465074  0.317131 -0.919276  1.490211
# 8  0.326436  0.057303 -0.369710  0.142607
# 9 -0.092879 -1.047611 -0.851693  0.631548
# <style type="text/css">
# #T_b74fa_row0_col0, #T_b74fa_row0_col1, #T_b74fa_row0_col2, #T_b74fa_row1_col2, #T_b74fa_row1_col3, #T_b74fa_row2_col2, #T_b74fa_row3_col0, #T_b74fa_row3_col3, #T_b74fa_row5_col0, #T_b74fa_row5_col1, #T_b74fa_row5_col2, #T_b74fa_row5_col3, #T_b74fa_row6_col2, #T_b74fa_row6_col3, #T_b74fa_row7_col2, #T_b74fa_row8_col2, #T_b74fa_row9_col0, #T_b74fa_row9_col1, #T_b74fa_row9_col2 {
#   color: red;
# }
# </style>
# <table id="T_b74fa">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b74fa_level0_col0" class="col_heading level0 col0" >A</th>
#       <th id="T_b74fa_level0_col1" class="col_heading level0 col1" >B</th>
#       <th id="T_b74fa_level0_col2" class="col_heading level0 col2" >C</th>
#       <th id="T_b74fa_level0_col3" class="col_heading level0 col3" >D</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b74fa_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_b74fa_row0_col0" class="data row0 col0" >-0.141269</td>
#       <td id="T_b74fa_row0_col1" class="data row0 col1" >-1.913170</td>
#       <td id="T_b74fa_row0_col2" class="data row0 col2" >-0.118287</td>
#       <td id="T_b74fa_row0_col3" class="data row0 col3" >0.129955</td>
#     </tr>
#     <tr>
#       <th id="T_b74fa_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_b74fa_row1_col0" class="data row1 col0" >0.553204</td>
#       <td id="T_b74fa_row1_col1" class="data row1 col1" >1.609483</td>
#       <td id="T_b74fa_row1_col2" class="data row1 col2" >-0.615517</td>
#       <td id="T_b74fa_row1_col3" class="data row1 col3" >-0.041524</td>
#     </tr>
#     <tr>
#       <th id="T_b74fa_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_b74fa_row2_col0" class="data row2 col0" >0.011620</td>
#       <td id="T_b74fa_row2_col1" class="data row2 col1" >2.429812</td>
#       <td id="T_b74fa_row2_col2" class="data row2 col2" >-0.508310</td>
#       <td id="T_b74fa_row2_col3" class="data row2 col3" >0.714850</td>
#     </tr>
#     <tr>
#       <th id="T_b74fa_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_b74fa_row3_col0" class="data row3 col0" >-0.270485</td>
#       <td id="T_b74fa_row3_col1" class="data row3 col1" >1.616712</td>
#       <td id="T_b74fa_row3_col2" class="data row3 col2" >0.469772</td>
#       <td id="T_b74fa_row3_col3" class="data row3 col3" >-0.991215</td>
#     </tr>
#     <tr>
#       <th id="T_b74fa_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_b74fa_row4_col0" class="data row4 col0" >1.558983</td>
#       <td id="T_b74fa_row4_col1" class="data row4 col1" >1.644725</td>
#       <td id="T_b74fa_row4_col2" class="data row4 col2" >1.566035</td>
#       <td id="T_b74fa_row4_col3" class="data row4 col3" >1.347889</td>
#     </tr>
#     <tr>
#       <th id="T_b74fa_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_b74fa_row5_col0" class="data row5 col0" >-0.756450</td>
#       <td id="T_b74fa_row5_col1" class="data row5 col1" >-0.417384</td>
#       <td id="T_b74fa_row5_col2" class="data row5 col2" >-0.296340</td>
#       <td id="T_b74fa_row5_col3" class="data row5 col3" >-0.257459</td>
#     </tr>
#     <tr>
#       <th id="T_b74fa_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_b74fa_row6_col0" class="data row6 col0" >0.154251</td>
#       <td id="T_b74fa_row6_col1" class="data row6 col1" >0.862215</td>
#       <td id="T_b74fa_row6_col2" class="data row6 col2" >-1.660832</td>
#       <td id="T_b74fa_row6_col3" class="data row6 col3" >-0.040017</td>
#     </tr>
#     <tr>
#       <th id="T_b74fa_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_b74fa_row7_col0" class="data row7 col0" >0.465074</td>
#       <td id="T_b74fa_row7_col1" class="data row7 col1" >0.317131</td>
#       <td id="T_b74fa_row7_col2" class="data row7 col2" >-0.919276</td>
#       <td id="T_b74fa_row7_col3" class="data row7 col3" >1.490211</td>
#     </tr>
#     <tr>
#       <th id="T_b74fa_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_b74fa_row8_col0" class="data row8 col0" >0.326436</td>
#       <td id="T_b74fa_row8_col1" class="data row8 col1" >0.057303</td>
#       <td id="T_b74fa_row8_col2" class="data row8 col2" >-0.369710</td>
#       <td id="T_b74fa_row8_col3" class="data row8 col3" >0.142607</td>
#     </tr>
#     <tr>
#       <th id="T_b74fa_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_b74fa_row9_col0" class="data row9 col0" >-0.092879</td>
#       <td id="T_b74fa_row9_col1" class="data row9 col1" >-1.047611</td>
#       <td id="T_b74fa_row9_col2" class="data row9 col2" >-0.851693</td>
#       <td id="T_b74fa_row9_col3" class="data row9 col3" >0.631548</td>
#     </tr>
#   </tbody>
# </table>
